# %%
# import module
from geopy.geocoders import Nominatim

# initialize Nominatim API 
geolocator = Nominatim(user_agent='Lou_311_EDA')

location = geolocator.geocode("407 Chenoweth Lane Druid Hills")
print(location.address)
# Out:
# 407, Chenoweth Lane, Cherrywood Village, Metro Council District 9, Druid Hills, Jefferson County, Kentucky, 40207, United States

# %%
# place input
place = "Boring road patna"
location = geolocator.geocode(place)

# traverse the data
data = location.raw
loc_data = data['display_name'].split()
print("Full Location")
print(loc_data)
print("Zip code : ",loc_data[-2])
